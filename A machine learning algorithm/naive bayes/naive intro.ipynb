# %%
[Window Title]
Visual Studio Code

[Content]
Error: EPERM: operation not permitted, rename 'c:\Users\Neema P Eldho\OneDrive\Desktop\numpy works\Regression' -> 'c:\Users\Neema P Eldho\OneDrive\Desktop\numpy works\A machine learning algorithm\Regression'

[OK]

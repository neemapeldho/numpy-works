# %% [markdown]
# API - Application programming interface
# ---------------------------------------
# communication between two different application (request,response) [can be client to server]
#
# Json      (api transfer format) - javascript object notation
# -----
# Json is a light weight format to transfer data across different application
#
#
# browser ----------------------> server
# browswer application <--------- server application        # eg : amazon.in  and swiggy

# %% [markdown]
# API
# ===
# >> Set of protocols which is used to communicate in between two different application
# >> request and response

# %% [markdown]
#                user_id
#         --------------------------->
# gpay                                    SBI                     (transfer like json)
#                account_balance
# (client)<---------------------------- (server)

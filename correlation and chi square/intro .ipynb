# %% [markdown]
# correlation
# ============
#
# df.corr()  - numeric column relation   correlation = 0.95(perfect)   0 - negative
#
# chi square - object column relation
#
#
# no_of_hours_studied(x)           marks(y)
#
#
# chi square
# ==========
#
# result  = row total * column total
#          --------------------------
#          grand total(row total + column total)
#
#
# chi square = E (initial value - result value) ^ 2
#                ------------------------------------
#                           result

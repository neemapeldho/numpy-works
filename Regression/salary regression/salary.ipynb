# %%
import pandas
import numpy

# %%
data = pandas.read_csv("Salary.csv")
df = pandas.DataFrame(data)
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from matplotlib import pyplot

pyplot.scatter(x,y,label="data point")
pyplot.xlabel("year of experience")
pyplot.ylabel("salary")
pyplot.title("salary v/s experience")
pyplot.legend() # label
pyplot.show()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

linear = LinearRegression()
linear = linear.fit(x_train,y_train)

y_pred = linear.predict(x_test)
y_pred
# Out:
# array([146318.57702832,  69007.08227808,  81033.31479478,  62134.94941139,
#         88764.46426981, 118830.04556157, 112816.92930321,  57839.86636971,
#         43236.584028  ,  47531.66706968, 111957.91269488])

# %%
y_test
# Out:
# 34    139465
# 14     61111
# 18     81363
# 9      57189
# 20     91738
# 28    122391
# 27    112635
# 7      54445
# 2      37731
# 3      43525
# 26    116969
# Name: Salary, dtype: int64

# %%
pyplot.scatter(x_train,y_train,color= "red")
pyplot.plot(x_test,y_pred)
pyplot.show()

# %%
print(linear.coef_)   # m 
print(linear.intercept_) # c
# Out:
# [8590.16608336]
# 30351.334902958966

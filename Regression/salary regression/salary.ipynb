# %%
import pandas
import numpy

# %%
data = pandas.read_csv("Salary.csv")
df = pandas.DataFrame(data)
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from matplotlib import pyplot

pyplot.scatter(x,y,label="data point")
pyplot.xlabel("year of experience")
pyplot.ylabel("salary")
pyplot.title("salary v/s experience")
pyplot.legend() # label
pyplot.show()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

linear = LinearRegression()
linear = linear.fit(x_train,y_train)

y_pred = linear.predict(x_test)
y_pred
# Out:
# array([ 54985.1983083 , 111777.56721313, 141484.34479413,  64596.2145845 ,
#         62848.75707973, 118767.39723219,  73333.50210832, 104787.73719408,
#         38384.35201304,  54111.46955591, 112651.29596552])

# %%
y_test
# Out:
# 6      60150
# 26    116969
# 33    135675
# 13     57081
# 10     63218
# 28    122391
# 16     66029
# 24    109431
# 0      39343
# 5      56642
# 27    112635
# Name: Salary, dtype: int64

# %%
pyplot.scatter(x_train,y_train,color= "red")
pyplot.plot(x_test,y_pred)
pyplot.show()

# %%
print(linear.coef_)   # m 
print(linear.intercept_) # c
# Out:
# [8737.28752382]
# 28773.335736832327

# %%
df2 = pandas.DataFrame({"actualvalue" : y_test,
                        "predicted_value " : y_pred,
                        "difference" : y_test - y_pred})

df2
# Out:
#     actualvalue  predicted_value    difference
# 6         60150      54985.198308  5164.801692
# 26       116969     111777.567213  5191.432787
# 33       135675     141484.344794 -5809.344794
# 13        57081      64596.214584 -7515.214584
# 10        63218      62848.757080   369.242920
# 28       122391     118767.397232  3623.602768
# 16        66029      73333.502108 -7304.502108
# 24       109431     104787.737194  4643.262806
# 0         39343      38384.352013   958.647987
# 5         56642      54111.469556  2530.530444
# 27       112635     112651.295966   -16.295966

# %%
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,y_pred))
# Out:
# 3920.625350552749

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred))
# Out:
# 21759856.529227834

# %%
from sklearn.metrics import root_mean_squared_error

print(root_mean_squared_error(y_test,y_pred))
# Out:
# 4664.74613770437

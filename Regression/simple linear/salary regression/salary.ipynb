# %%
import pandas
import numpy

# %%
data = pandas.read_csv("Salary.csv")
df = pandas.DataFrame(data)
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from matplotlib import pyplot

pyplot.scatter(x,y,label="data point")
pyplot.xlabel("year of experience")
pyplot.ylabel("salary")
pyplot.title("salary v/s experience")
pyplot.legend() # label
pyplot.show()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

linear = LinearRegression()
linear = linear.fit(x_train,y_train)

y_pred = linear.predict(x_test)
y_pred
# Out:
# array([ 63999.07548043, 100809.39003594,  65711.18313417, 118786.52040027,
#         47734.05276985,  69135.39844166,  43453.78363549,  81120.15201788,
#        129059.16632274,  58006.69869232, 135907.59693772])

# %%
y_test
# Out:
# 10     63218
# 23    113812
# 13     57081
# 28    122391
# 3      43525
# 14     61111
# 2      37731
# 18     81363
# 31    126756
# 7      54445
# 32    128765
# Name: Salary, dtype: int64

# %%
pyplot.scatter(x_train,y_train,color= "red")
pyplot.plot(x_test,y_pred)
pyplot.show()

# %%
print(linear.coef_)   # m 
print(linear.intercept_) # c
# Out:
# [8560.53826873]
# 30612.976232399305

# %%
df2 = pandas.DataFrame({"actualvalue" : y_test,
                        "predicted_value " : y_pred,
                        "difference" : y_test - y_pred})

df2
# Out:
#     actualvalue  predicted_value     difference
# 10        63218      63999.075480   -781.075480
# 23       113812     100809.390036  13002.609964
# 13        57081      65711.183134  -8630.183134
# 28       122391     118786.520400   3604.479600
# 3         43525      47734.052770  -4209.052770
# 14        61111      69135.398442  -8024.398442
# 2         37731      43453.783635  -5722.783635
# 18        81363      81120.152018    242.847982
# 31       126756     129059.166323  -2303.166323
# 7         54445      58006.698692  -3561.698692
# 32       128765     135907.596938  -7142.596938

# %%
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,y_pred))
# Out:
# 5202.262996389245

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred))
# Out:
# 40097596.89530899

# %%
from sklearn.metrics import root_mean_squared_error

print(root_mean_squared_error(y_test,y_pred))
# Out:
# 6332.266331678492

# %%
from sklearn.metrics import mean_absolute_percentage_error

print(mean_absolute_percentage_error(y_test,y_pred))
# Out:
# 0.07536120709146618

# %%
from sklearn.metrics import r2_score

print(r2_score(y_test,y_pred))
# Out:
# 0.9645172927194696
